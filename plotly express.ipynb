# %%
import pandas as pd
import numpy as np
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('./climate_change_data.csv',parse_dates=['Date'])
data.head()
# Out:
#                            Date          Location        Country  Temperature  \
# 0 2000-01-01 00:00:00.000000000   New Williamtown         Latvia    10.688986
# 1 2000-01-01 20:09:43.258325832      North Rachel   South Africa    13.814430
# 2 2000-01-02 16:19:26.516651665  West Williamland  French Guiana    27.323718
# 3 2000-01-03 12:29:09.774977497       South David        Vietnam    12.309581
# 4 2000-01-04 08:38:53.033303330    New Scottburgh        Moldova    13.210885
#
#    CO2 Emissions  Sea Level Rise  Precipitation   Humidity  Wind Speed
# 0     403.118903        0.717506      13.835237  23.631256   18.492026
# 1     396.663499        1.205715      40.974084  43.982946   34.249300
# 2     451.553155       -0.160783      42.697931  96.652600   34.124261
# 3     422.404983       -0.475931       5.193341  47.467938    8.554563
# 4     410.472999        1.135757      78.695280  61.789672    8.001164

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            10000 non-null  datetime64[ns]
#  1   Location        10000 non-null  object
#  2   Country         10000 non-null  object
#  3   Temperature     10000 non-null  float64
#  4   CO2 Emissions   10000 non-null  float64
#  5   Sea Level Rise  10000 non-null  float64
#  6   Precipitation   10000 non-null  float64
#  7   Humidity        10000 non-null  float64
#  8   Wind Speed      10000 non-null  float64
# dtypes: datetime64[ns](1), float64(6), object(2)
# memory usage: 703.2+ KB

# %%
data.isnull().sum()
# Out:
# Date              0
# Location          0
# Country           0
# Temperature       0
# CO2 Emissions     0
# Sea Level Rise    0
# Precipitation     0
# Humidity          0
# Wind Speed        0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.shape
# Out:
# (10000, 9)

# %%
data['Time'] = data.Date.dt.time
data['Year'] = data.Date.dt.year
data['Month'] = data.Date.dt.month
data['Day'] = data.Date.dt.day

# %%
data.head()
# Out:
#                            Date          Location        Country  Temperature  \
# 0 2000-01-01 00:00:00.000000000   New Williamtown         Latvia    10.688986
# 1 2000-01-01 20:09:43.258325832      North Rachel   South Africa    13.814430
# 2 2000-01-02 16:19:26.516651665  West Williamland  French Guiana    27.323718
# 3 2000-01-03 12:29:09.774977497       South David        Vietnam    12.309581
# 4 2000-01-04 08:38:53.033303330    New Scottburgh        Moldova    13.210885
#
#    CO2 Emissions  Sea Level Rise  Precipitation   Humidity  Wind Speed  \
# 0     403.118903        0.717506      13.835237  23.631256   18.492026
# 1     396.663499        1.205715      40.974084  43.982946   34.249300
# 2     451.553155       -0.160783      42.697931  96.652600   34.124261
# 3     422.404983       -0.475931       5.193341  47.467938    8.554563
# 4     410.472999        1.135757      78.695280  61.789672    8.001164
#
#               Time  Year  Month  Day
# ...

# %%
data.drop(columns='Date',inplace=True)

# %%
data
# Out:
#                Location                Country  Temperature  CO2 Emissions  \
# 0       New Williamtown                 Latvia    10.688986     403.118903
# 1          North Rachel           South Africa    13.814430     396.663499
# 2      West Williamland          French Guiana    27.323718     451.553155
# 3           South David                Vietnam    12.309581     422.404983
# 4        New Scottburgh                Moldova    13.210885     410.472999
# ...                 ...                    ...          ...            ...
# 9995   South Elaineberg                 Bhutan    15.020523     391.379537
# 9996       Leblancville                  Congo    16.772451     346.921190
# 9997     West Stephanie              Argentina    22.370025     466.042136
# 9998        Port Steven                Albania    19.430853     337.899776
# 9999  West Anthonyburgh  Sao Tome and Principe    12.661928     381.172746
#
# ...

# %%
data.value_counts()
# Out:
# Location        Country                Temperature  CO2 Emissions  Sea Level Rise  Precipitation  Humidity   Wind Speed  Time             Year  Month  Day
# Aaronberg       France                 14.976998    406.437367      0.851594       3.337966       88.162996  2.952806    04:46:52.601260  2002  3      3      1
# Port Chelsea    Jamaica                18.214684    395.163028     -1.052494       18.240583      7.255567   6.380022    02:35:58.055805  2008  6      10     1
# Port Catherine  Portugal               7.926596     349.517680      0.925205       73.819145      31.854684  10.435009   18:16:31.539153  2003  4      29     1
#                 Reunion                9.445787     422.917241      0.989807       50.257037      26.761362  5.634868    18:54:32.727272  2009  7      10     1
# Port Charles    Algeria                9.787307     397.884393      1.159498       55.089545      89.959624  25.561192   05:29:38.937893  2013  12     7      1
# ...

# %%
data.Year.unique()
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021,
#        2022], dtype=int64)

# %%
data.columns
# Out:
# Index(['Location', 'Country', 'Temperature', 'CO2 Emissions', 'Sea Level Rise',
#        'Precipitation', 'Humidity', 'Wind Speed', 'Time', 'Year', 'Month',
#        'Day'],
#       dtype='object')

# %%
data.rename(columns={'CO2 Emissions':'CO2_Emissions',\
                     'Sea Level Rise':'Sea_Level_Rise','Wind Speed':'Wind_Speed'},inplace=True)

# %%
data
# Out:
#                Location                Country  Temperature  CO2_Emissions  \
# 0       New Williamtown                 Latvia    10.688986     403.118903
# 1          North Rachel           South Africa    13.814430     396.663499
# 2      West Williamland          French Guiana    27.323718     451.553155
# 3           South David                Vietnam    12.309581     422.404983
# 4        New Scottburgh                Moldova    13.210885     410.472999
# ...                 ...                    ...          ...            ...
# 9995   South Elaineberg                 Bhutan    15.020523     391.379537
# 9996       Leblancville                  Congo    16.772451     346.921190
# 9997     West Stephanie              Argentina    22.370025     466.042136
# 9998        Port Steven                Albania    19.430853     337.899776
# 9999  West Anthonyburgh  Sao Tome and Principe    12.661928     381.172746
#
# ...

# %%
data.CO2_Emissions.nlargest(10)
# Out:
# 442     582.899701
# 5886    576.650885
# 3662    576.498970
# 649     575.653710
# 4004    572.692033
# 8444    565.778153
# 1689    563.507328
# 4560    563.021171
# 1888    560.281225
# 3991    557.136550
# Name: CO2_Emissions, dtype: float64

# %%
data.Country.nunique()
# Out:
# 243

# %%
data.Temperature.nlargest(10)
# Out:
# 5601    33.976956
# 9228    33.907976
# 4370    32.745123
# 2839    32.403159
# 2224    31.455420
# 6347    31.221108
# 5949    31.092676
# 3408    30.866866
# 7667    30.844262
# 1654    30.816299
# Name: Temperature, dtype: float64

# %%
data.describe().T
# Out:
#                   count         mean        std          min          25%  \
# Temperature     10000.0    14.936034   5.030616    -3.803589    11.577991
# CO2_Emissions   10000.0   400.220469  49.696933   182.131220   367.109330
# Sea_Level_Rise  10000.0    -0.003152   0.991349    -4.092155    -0.673809
# Precipitation   10000.0    49.881208  28.862417     0.010143    24.497516
# Humidity        10000.0    49.771302  28.929320     0.018998    24.713250
# Wind_Speed      10000.0    25.082066  14.466648     0.001732    12.539733
# Year            10000.0  2010.997900   6.633634  2000.000000  2005.000000
# Month           10000.0     6.523100   3.448718     1.000000     4.000000
# Day             10000.0    15.727100   8.800816     1.000000     8.000000
#
#                         50%          75%          max
# Temperature       14.981136    18.305826    33.976956
# CO2_Emissions    400.821324   433.307905   582.899701
# Sea_Level_Rise     0.002332     0.675723     4.116559
# ...

# %%
data.sort_values(by=['Year','Month'],inplace=True)
data
# Out:
#                Location                Country  Temperature  CO2_Emissions  \
# 0       New Williamtown                 Latvia    10.688986     403.118903
# 1          North Rachel           South Africa    13.814430     396.663499
# 2      West Williamland          French Guiana    27.323718     451.553155
# 3           South David                Vietnam    12.309581     422.404983
# 4        New Scottburgh                Moldova    13.210885     410.472999
# ...                 ...                    ...          ...            ...
# 9995   South Elaineberg                 Bhutan    15.020523     391.379537
# 9996       Leblancville                  Congo    16.772451     346.921190
# 9997     West Stephanie              Argentina    22.370025     466.042136
# 9998        Port Steven                Albania    19.430853     337.899776
# 9999  West Anthonyburgh  Sao Tome and Principe    12.661928     381.172746
#
# ...

# %%
temp_per_year = data.groupby(['Year','Month'])['Temperature'].mean()
temp_per_year
# Out:
# Year  Month
# 2000  1        14.206357
#       2        13.932424
#       3        16.353462
#       4        14.956865
#       5        15.447593
#                  ...
# 2022  8        14.516170
#       9        14.715461
#       10       14.762771
#       11       16.138990
#       12       15.065756
# Name: Temperature, Length: 276, dtype: float64

# %% [markdown]
# ### Histogram

# %%
hist = px.histogram(data_frame=temp_per_year,x='Temperature')
hist.show()
# Out:
# <div>                            <div id="761bcf2c-1d89-4b24-a815-cfc309c288b7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("761bcf2c-1d89-4b24-a815-cfc309c288b7")) {                    Plotly.newPlot(                        "761bcf2c-1d89-4b24-a815-cfc309c288b7",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Temperature=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[14.206356635840503,13.932424493784556,16.353461941121843,14.956865367646007,15.447593479944507,15.312804836628832,15.628545568934678,15.079403128302943,14.245601056285295,14.634585506129746,15.79159409065817,14.74704401987529
# ...

# %% [markdown]
# ### Box plots

# %%
box_fig = px.box(data,y='Wind_Speed')
box_fig.show()
# Out:
# <div>                            <div id="e7e92bad-cc02-4674-94d0-d0d2cbd3abd2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e7e92bad-cc02-4674-94d0-d0d2cbd3abd2")) {                    Plotly.newPlot(                        "e7e92bad-cc02-4674-94d0-d0d2cbd3abd2",                        [{"alignmentgroup":"True","hovertemplate":"Wind_Speed=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[18.492026001060687,34.24929982477023,34.12426102508349,8.554563363421174,8.001163673482758,30.39890794329896,15.720943642696325,29.99349506057048,37.51947246463215,47.92252054153893,20.88834143678071,30.43540963729574,1.833402038880011,23.38
# ...

# %%
hum_box = px.
