# %%
import pandas as pd

# %%
data = pd.read_csv('./titanic.csv')

# %% [markdown]
# ## Head

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare  ... Embarked WikiId  \
# 0      0         A/5 21171   7.2500  ...        S  691.0
# 1      0          PC 17599  71.2833  ...        C   90.0
# 2      0  STON/O2. 3101282   7.9250  ...        S  865.0
# 3      0            113803  53.1000  ...        S  127.0
# ...

# %%
data.head(14)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1       0.0       3
# 1             2       1.0       1
# 2             3       1.0       3
# 3             4       1.0       1
# 4             5       0.0       3
# 5             6       0.0       3
# 6             7       0.0       1
# 7             8       0.0       3
# 8             9       1.0       3
# 9            10       1.0       2
# 10           11       1.0       3
# 11           12       1.0       1
# 12           13       0.0       3
# 13           14       0.0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
data.tail(9)
# Out:
#       PassengerId  Survived  Pclass  \
# 1300         1301       NaN       3
# 1301         1302       NaN       3
# 1302         1303       NaN       1
# 1303         1304       NaN       3
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                  Name     Sex   Age  SibSp  \
# 1300                        Peacock, Miss. Treasteall  female   3.0      1
# 1301                           Naughton, Miss. Hannah  female   NaN      0
# 1302  Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 1303                   Henriksson, Miss. Jenny Lovisa  female  28.0      0
# 1304                               Spector, Mr. Woolf    male   NaN      0
# 1305                     Oliva y Ocana, Dona. Fermina  female  39.0      0
# ...

# %%
data.sample()
# Out:
#      PassengerId  Survived  Pclass  \
# 600          601       1.0       2
#
#                                                   Name     Sex   Age  SibSp  \
# 600  Jacobsohn, Mrs. Sidney Samuel (Amy Frances Chr...  female  24.0      2
#
#      Parch  Ticket  Fare  ... Embarked WikiId  \
# 600      1  243847  27.0  ...        S  466.0
#
#                                            Name_wiki Age_wiki  \
# 600  Jacobsohn, Mrs. Amy Frances Christy (née Cohen)     24.0
#
#             Hometown      Boarded               Destination Lifeboat Body  \
# 600  London, England  Southampton  Montreal, Quebec, Canada       12  NaN
#
#     Class
# 600   2.0
#
# [1 rows x 21 columns]

# %%
data.sample(10)
# Out:
#       PassengerId  Survived  Pclass  \
# 1092         1093       NaN       3
# 916           917       NaN       3
# 599           600       1.0       1
# 204           205       1.0       3
# 240           241       0.0       3
# 424           425       0.0       3
# 748           749       0.0       1
# 790           791       0.0       3
# 404           405       0.0       3
# 78             79       1.0       2
#
#                                               Name     Sex    Age  SibSp  \
# 1092       Danbom, Master. Gilbert Sigvard Emanuel    male   0.33      0
# 916                        Robins, Mr. Alexander A    male  50.00      1
# 599   Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")    male  49.00      1
# 204                       Cohen, Mr. Gurshon "Gus"    male  18.00      0
# 240                          Zabour, Miss. Thamine  female    NaN      1
# 424                    Rosblom, Mr. Viktor Richard    male  18.00      1
# ...

# %%
data.describe().T
# Out:
#               count        mean         std   min       25%       50%  \
# PassengerId  1309.0  655.000000  378.020061  1.00  328.0000  655.0000
# Survived      891.0    0.383838    0.486592  0.00    0.0000    0.0000
# Pclass       1309.0    2.294882    0.837836  1.00    2.0000    3.0000
# Age          1046.0   29.881138   14.413493  0.17   21.0000   28.0000
# SibSp        1309.0    0.498854    1.041658  0.00    0.0000    0.0000
# Parch        1309.0    0.385027    0.865560  0.00    0.0000    0.0000
# Fare         1308.0   33.295479   51.758668  0.00    7.8958   14.4542
# WikiId       1304.0  658.534509  380.377373  1.00  326.7500  661.5000
# Age_wiki     1302.0   29.415829   13.758954  0.17   21.0000   28.0000
# Class        1304.0    2.291411    0.840852  1.00    1.7500    3.0000
#
#                  75%        max
# PassengerId  982.000  1309.0000
# Survived       1.000     1.0000
# Pclass         3.000     3.0000
# Age           39.000    80.0000
# ...

# %%
data.describe()
# Out:
#        PassengerId    Survived       Pclass          Age        SibSp  \
# count  1309.000000  891.000000  1309.000000  1046.000000  1309.000000
# mean    655.000000    0.383838     2.294882    29.881138     0.498854
# std     378.020061    0.486592     0.837836    14.413493     1.041658
# min       1.000000    0.000000     1.000000     0.170000     0.000000
# 25%     328.000000    0.000000     2.000000    21.000000     0.000000
# 50%     655.000000    0.000000     3.000000    28.000000     0.000000
# 75%     982.000000    1.000000     3.000000    39.000000     1.000000
# max    1309.000000    1.000000     3.000000    80.000000     8.000000
#
#              Parch         Fare       WikiId     Age_wiki        Class
# count  1309.000000  1308.000000  1304.000000  1302.000000  1304.000000
# mean      0.385027    33.295479   658.534509    29.415829     2.291411
# std       0.865560    51.758668   380.377373    13.758954     0.840852
# ...

# %%
data.shape
# Out:
# (1309, 21)

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'WikiId', 'Name_wiki',
#        'Age_wiki', 'Hometown', 'Boarded', 'Destination', 'Lifeboat', 'Body',
#        'Class'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
#  12  WikiId       1304 non-null   float64
#  13  Name_wiki    1304 non-null   object
#  14  Age_wiki     1302 non-null   float64
#  15  Hometown     1304 non-null   object
#  16  Boarded      1304 non-null   object
#  17  Destination  1304 non-null   object
# ...

# %% [markdown]
# Null values

# %%
data.isnull().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# WikiId            5
# Name_wiki         5
# Age_wiki          7
# Hometown          5
# Boarded           5
# Destination       5
# Lifeboat        807
# Body           1179
# Class             5
# dtype: int64

# %% [markdown]
# ## Null percentage

# %%
data.isnull().mean()
# Out:
# PassengerId    0.000000
# Survived       0.319328
# Pclass         0.000000
# Name           0.000000
# Sex            0.000000
# Age            0.200917
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# Fare           0.000764
# Cabin          0.774637
# Embarked       0.001528
# WikiId         0.003820
# Name_wiki      0.003820
# Age_wiki       0.005348
# Hometown       0.003820
# Boarded        0.003820
# Destination    0.003820
# Lifeboat       0.616501
# Body           0.900688
# Class          0.003820
# dtype: float64

# %%
data.isnull().mean()*100
# Out:
# PassengerId     0.000000
# Survived       31.932773
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            20.091673
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.076394
# Cabin          77.463713
# Embarked        0.152788
# WikiId          0.381971
# Name_wiki       0.381971
# Age_wiki        0.534759
# Hometown        0.381971
# Boarded         0.381971
# Destination     0.381971
# Lifeboat       61.650115
# Body           90.068755
# Class           0.381971
# dtype: float64

# %% [markdown]
# ### Dropping the columns

# %%
data.drop(columns=['Body','Lifeboat','Cabin','PassengerId'])
# Out:
#       Survived  Pclass                                               Name  \
# 0          0.0       3                            Braund, Mr. Owen Harris
# 1          1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1.0       3                             Heikkinen, Miss. Laina
# 3          1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0.0       3                           Allen, Mr. William Henry
# ...        ...     ...                                                ...
# 1304       NaN       3                                 Spector, Mr. Woolf
# 1305       NaN       1                       Oliva y Ocana, Dona. Fermina
# 1306       NaN       3                       Saether, Mr. Simon Sivertsen
# 1307       NaN       3                                Ware, Mr. Frederick
# 1308       NaN       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket      Fare Embarked  \
# ...

# %%
data
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
data.drop(columns=['Body','Lifeboat','Cabin','PassengerId'], inplace=True)

# %%
data
# Out:
#       Survived  Pclass                                               Name  \
# 0          0.0       3                            Braund, Mr. Owen Harris
# 1          1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1.0       3                             Heikkinen, Miss. Laina
# 3          1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0.0       3                           Allen, Mr. William Henry
# ...        ...     ...                                                ...
# 1304       NaN       3                                 Spector, Mr. Woolf
# 1305       NaN       1                       Oliva y Ocana, Dona. Fermina
# 1306       NaN       3                       Saether, Mr. Simon Sivertsen
# 1307       NaN       3                                Ware, Mr. Frederick
# 1308       NaN       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket      Fare Embarked  \
# ...

# %%
data.sample()
# Out:
#       Survived  Pclass                      Name   Sex   Age  SibSp  Parch  \
# 1095       NaN       2  Andrew, Mr. Frank Thomas  male  25.0      0      0
#
#           Ticket  Fare Embarked  WikiId                 Name_wiki  Age_wiki  \
# 1095  C.A. 34050  10.5        S   330.0  Andrew, Mr. Frank Thomas      30.0
#
#                         Hometown      Boarded             Destination  Class
# 1095  Redruth, Cornwall, England  Southampton  Houghton, Michigan, US    2.0

# %%
data.Survived.unique()
# Out:
# array([ 0.,  1., nan])

# %%
data.Pclass.unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
data.Sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
data.Age.unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  , 22.5 ,
#        18.5 , 67.  , 76.  , 26.5 , 60.5 , 11.5 ,  0.33,  0.17, 38.5 ])

# %%
data.Sex.value_counts()
# Out:
# male      843
# female    466
# Name: Sex, dtype: int64

# %%
data.Embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %% [markdown]
# ## Filling NaN values

# %%
data.Embarked.value_counts()
# Out:
# S    914
# C    270
# Q    123
# Name: Embarked, dtype: int64

# %%
data.Embarked.fillna("S",inplace=True)

# %%
data.isnull().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age            263
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Embarked         0
# WikiId           5
# Name_wiki        5
# Age_wiki         7
# Hometown         5
# Boarded          5
# Destination      5
# Class            5
# dtype: int64

# %%
data.Fare.mean()
# Out:
# 33.2954792813456

# %%
Fare_mean = data.Fare.mean()

# %%
data.Fare.fillna(Fare_mean,inplace=True)

# %%
data
# Out:
#       Survived  Pclass                                               Name  \
# 0          0.0       3                            Braund, Mr. Owen Harris
# 1          1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1.0       3                             Heikkinen, Miss. Laina
# 3          1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0.0       3                           Allen, Mr. William Henry
# ...        ...     ...                                                ...
# 1304       NaN       3                                 Spector, Mr. Woolf
# 1305       NaN       1                       Oliva y Ocana, Dona. Fermina
# 1306       NaN       3                       Saether, Mr. Simon Sivertsen
# 1307       NaN       3                                Ware, Mr. Frederick
# 1308       NaN       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket      Fare Embarked  \
# ...

# %%
data.isnull().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age            263
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# WikiId           5
# Name_wiki        5
# Age_wiki         7
# Hometown         5
# Boarded          5
# Destination      5
# Class            5
# dtype: int64

# %%
data.WikiId.unique()
# Out:
# array([ 691.,   90.,  865., ..., 1169., 1289.,  702.])

# %%
data.WikiId.fillna(700,inplace=True)

# %%
data
# Out:
#       Survived  Pclass                                               Name  \
# 0          0.0       3                            Braund, Mr. Owen Harris
# 1          1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1.0       3                             Heikkinen, Miss. Laina
# 3          1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0.0       3                           Allen, Mr. William Henry
# ...        ...     ...                                                ...
# 1304       NaN       3                                 Spector, Mr. Woolf
# 1305       NaN       1                       Oliva y Ocana, Dona. Fermina
# 1306       NaN       3                       Saether, Mr. Simon Sivertsen
# 1307       NaN       3                                Ware, Mr. Frederick
# 1308       NaN       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket      Fare Embarked  \
# ...

# %%
data.isnull().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age            263
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# WikiId           0
# Name_wiki        5
# Age_wiki         7
# Hometown         5
# Boarded          5
# Destination      5
# Class            5
# dtype: int64

# %%
data.Class.unique()
# Out:
# array([ 3.,  1.,  2., nan])

# %%
data.Class.value_counts()
# Out:
# 3.0    706
# 1.0    326
# 2.0    272
# Name: Class, dtype: int64

# %%
data.Class.fillna(3.0,inplace=True)

# %%
data.isnull().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age            263
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# WikiId           0
# Name_wiki        5
# Age_wiki         7
# Hometown         5
# Boarded          5
# Destination      5
# Class            0
# dtype: int64

# %%
data.Destination.unique()
# Out:
# array(["Qu'Appelle Valley, Saskatchewan, Canada",
#        'New York, New York, US', 'New York City',
#        'Scituate, Massachusetts, US', 'Dorchester, Massachusetts, US',
#        'Chicago, Illinois, US', 'St. Charles, Illinois, US',
#        'Cleveland, Ohio, US', 'San Francisco, US', 'Youngstown, Ohio, US',
#        'Winnipeg, Manitoba, Canada', 'Los Angeles, US',
#        'Rapid City, South Dakota, US', 'Spokane, Washington, US',
#        'Fremont, Ohio, US', 'Michigan City, Indiana, US',
#        'Montreal, Quebec, Canada', 'Toronto, Ontario, Canada',
#        'New Britain, Connecticut, US', 'Worcester, Massachusetts, US',
#        'Mexico City, Mexico', 'Washington, DC, US',
#        'Edgewood, Rhode Island, US', 'Philadelphia, Pennsylvania, US',
#        'Jacksonville, Florida, US', 'Akeley, Minnesota, US',
#        'Salt Lake City, Utah, US', 'Madison, Wisconsin, US',
#        'Cap-Haïtien, Haiti', 'Jersey City, New Jersey, US',
# ...

# %%
data.Destination.value_counts()
# Out:
# New York City                          234
# New York, New York, US                 127
# Chicago, Illinois, US                   75
# Montreal, Quebec, Canada                37
# Detroit, Michigan, US                   28
#                                       ...
# East Bridgewater, Massachusetts, US      1
# Oregon, Wisconsin, US                    1
# Rahway, New Jersey, US                   1
# Stoughton, Massachusetts                 1
# US                                       1
# Name: Destination, Length: 291, dtype: int64

# %%
data.Destination.fillna("New York City",inplace=True)

# %%
data.isnull().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age            263
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# WikiId           0
# Name_wiki        5
# Age_wiki         7
# Hometown         5
# Boarded          5
# Destination      0
# Class            0
# dtype: int64

# %%
data.Boarded.unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown', 'Belfast', nan],
#       dtype=object)

# %%
data.Boarded.value_counts()
# Out:
# Southampton    916
# Cherbourg      259
# Queenstown     119
# Belfast         10
# Name: Boarded, dtype: int64

# %%
data.Boarded.fillna("Southampton",inplace=True)

# %%
data.isnull().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age            263
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# WikiId           0
# Name_wiki        5
# Age_wiki         7
# Hometown         5
# Boarded          0
# Destination      0
# Class            0
# dtype: int64

# %%
data.Hometown.value_counts()
# Out:
# New York, New York, US                70
# London, England                       49
# London, England, UK                   30
# Paris, France                         23
# Montreal, Quebec, Canada              20
#                                       ..
# Avaldsnes, Stavanger, Norway           1
# Marbella, Spain                        1
# Västermo, Södermanland, Sweden         1
# Trollhättan, Västergötland, Sweden     1
# Sar'al[81], Syria                      1
# Name: Hometown, Length: 566, dtype: int64

# %%
data.Hometown.fillna("New York, New York, US",inplace=True)

# %%
data.isnull().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age            263
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# WikiId           0
# Name_wiki        5
# Age_wiki         7
# Hometown         0
# Boarded          0
# Destination      0
# Class            0
# dtype: int64

# %%
data.Age_wiki.value_counts()
# Out:
# 22.00    62
# 24.00    56
# 21.00    51
# 28.00    47
# 18.00    46
#          ..
# 74.00     1
# 67.00     1
# 0.33      1
# 0.58      1
# 0.17      1
# Name: Age_wiki, Length: 78, dtype: int64

# %%
data.Age_wiki.fillna(22.00,inplace=True)

# %%
data.isnull().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age            263
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# WikiId           0
# Name_wiki        5
# Age_wiki         0
# Hometown         0
# Boarded          0
# Destination      0
# Class            0
# dtype: int64

# %%
data.Name_wiki.value_counts()
# Out:
# Kelly, Mr. James                                 2
# Petroff, Mr. Nadjalko                            1
# Zajib Qiyamah, Miss Adal "Jane"                  1
# Abelson, Mrs. Anna (née Wizosky?)                1
# Vandercruyssen, Mr. Victor                       1
#                                                 ..
# Silvey, Mr. William Baird                        1
# Kallio, Mr. Nikolai Erlantti                     1
# Louch, Mrs. Alice Adelaide (née Slow)            1
# Thorneycroft, Mrs. Florence Kate (née Stears)    1
# Butrus-Youssef, Master Makhkhul                  1
# Name: Name_wiki, Length: 1303, dtype: int64

# %%
data.Name_wiki.fillna("Kelly,Mr. Victor",inplace=True)

# %%
data.isnull().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age            263
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# WikiId           0
# Name_wiki        0
# Age_wiki         0
# Hometown         0
# Boarded          0
# Destination      0
# Class            0
# dtype: int64

# %%
data.Age.value_counts()
# Out:
# 24.0    47
# 22.0    43
# 21.0    41
# 30.0    40
# 18.0    39
#         ..
# 23.5     1
# 70.5     1
# 55.5     1
# 20.5     1
# 38.5     1
# Name: Age, Length: 98, dtype: int64

# %%
data.Age.fillna(24.0,inplace=True)

# %%
# data["Age"]=data["Age"].astype("int64")

# %%
# data.Age.dtype

# %%
# data.Age.value_counts()

# %%
data.isnull().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# WikiId           0
# Name_wiki        0
# Age_wiki         0
# Hometown         0
# Boarded          0
# Destination      0
# Class            0
# dtype: int64

# %%
data.Survived.value_counts()
# Out:
# 0.0    549
# 1.0    342
# Name: Survived, dtype: int64

# %%
data.Survived.fillna(1.0,inplace=True)

# %%
data.isnull().sum()
# Out:
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# WikiId         0
# Name_wiki      0
# Age_wiki       0
# Hometown       0
# Boarded        0
# Destination    0
# Class          0
# dtype: int64

# %%
data
# Out:
#       Survived  Pclass                                               Name  \
# 0          0.0       3                            Braund, Mr. Owen Harris
# 1          1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1.0       3                             Heikkinen, Miss. Laina
# 3          1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0.0       3                           Allen, Mr. William Henry
# ...        ...     ...                                                ...
# 1304       1.0       3                                 Spector, Mr. Woolf
# 1305       1.0       1                       Oliva y Ocana, Dona. Fermina
# 1306       1.0       3                       Saether, Mr. Simon Sivertsen
# 1307       1.0       3                                Ware, Mr. Frederick
# 1308       1.0       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket      Fare Embarked  \
# ...

# %%
data.sample()
# Out:
#      Survived  Pclass                       Name     Sex   Age  SibSp  Parch  \
# 419       0.0       3  Van Impe, Miss. Catharina  female  10.0      0      2
#
#      Ticket   Fare Embarked  WikiId                 Name_wiki  Age_wiki  \
# 419  345773  24.15        S  1276.0  Van Impe, Miss Catharina      10.0
#
#               Hometown      Boarded            Destination  Class
# 419  Kerksken, Belgium  Southampton  Detroit, Michigan, US    3.0

# %%
data.drop(columns=['SibSp','Parch','WikiId','Name_wiki','Age_wiki'],inplace=True)

# %%
data.isnull().sum()
# Out:
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# Ticket         0
# Fare           0
# Embarked       0
# Hometown       0
# Boarded        0
# Destination    0
# Class          0
# dtype: int64

# %%
data
# Out:
#       Survived  Pclass                                               Name  \
# 0          0.0       3                            Braund, Mr. Owen Harris
# 1          1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1.0       3                             Heikkinen, Miss. Laina
# 3          1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0.0       3                           Allen, Mr. William Henry
# ...        ...     ...                                                ...
# 1304       1.0       3                                 Spector, Mr. Woolf
# 1305       1.0       1                       Oliva y Ocana, Dona. Fermina
# 1306       1.0       3                       Saether, Mr. Simon Sivertsen
# 1307       1.0       3                                Ware, Mr. Frederick
# 1308       1.0       3                           Peter, Master. Michael J
#
#          Sex   Age              Ticket      Fare Embarked  \
# ...

# %% [markdown]
# #### Grouping and query

# %%
data
# Out:
#       Survived  Pclass                                               Name  \
# 0          0.0       3                            Braund, Mr. Owen Harris
# 1          1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1.0       3                             Heikkinen, Miss. Laina
# 3          1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0.0       3                           Allen, Mr. William Henry
# ...        ...     ...                                                ...
# 1304       1.0       3                                 Spector, Mr. Woolf
# 1305       1.0       1                       Oliva y Ocana, Dona. Fermina
# 1306       1.0       3                       Saether, Mr. Simon Sivertsen
# 1307       1.0       3                                Ware, Mr. Frederick
# 1308       1.0       3                           Peter, Master. Michael J
#
#          Sex   Age              Ticket      Fare Embarked  \
# ...

# %%
Sex_Survived = data.groupby(["Sex"])["Survived"].sum()
Sex_Survived
# Out:
# Sex
# female    385.0
# male      375.0
# Name: Survived, dtype: float64

# %%
Pclass_Survived = data.groupby(["Pclass"])["Survived"].sum()
Pclass_Survived
# Out:
# Pclass
# 1    243.0
# 2    180.0
# 3    337.0
# Name: Survived, dtype: float64

# %%
Age_Survived = data.groupby(["Age"])["Survived"]
Age_Survived.value_counts()
# Out:
# Age    Survived
# 0.17   1.0         1
# 0.33   1.0         1
# 0.42   1.0         1
# 0.67   1.0         1
# 0.75   1.0         3
#                   ..
# 70.50  0.0         1
# 71.00  0.0         2
# 74.00  0.0         1
# 76.00  1.0         1
# 80.00  1.0         1
# Name: Survived, Length: 163, dtype: int64

# %%
data.Age.unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  , 24.  , 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 46.  , 59.  , 71.  ,
#        37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 , 51.  ,
#        55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  , 45.5 ,
#        20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  , 60.  ,
#        10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  , 70.  ,
#        24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  , 22.5 , 18.5 ,
#        67.  , 76.  , 26.5 , 60.5 , 11.5 ,  0.33,  0.17, 38.5 ])

# %%
data.Age.value_counts()
# Out:
# 24.0    310
# 22.0     43
# 21.0     41
# 30.0     40
# 18.0     39
#        ...
# 23.5      1
# 70.5      1
# 55.5      1
# 20.5      1
# 38.5      1
# Name: Age, Length: 98, dtype: int64

# %%
data
# Out:
#       Survived  Pclass                                               Name  \
# 0          0.0       3                            Braund, Mr. Owen Harris
# 1          1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1.0       3                             Heikkinen, Miss. Laina
# 3          1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0.0       3                           Allen, Mr. William Henry
# ...        ...     ...                                                ...
# 1304       1.0       3                                 Spector, Mr. Woolf
# 1305       1.0       1                       Oliva y Ocana, Dona. Fermina
# 1306       1.0       3                       Saether, Mr. Simon Sivertsen
# 1307       1.0       3                                Ware, Mr. Frederick
# 1308       1.0       3                           Peter, Master. Michael J
#
#          Sex   Age              Ticket      Fare Embarked  \
# ...

# %%
Destination_Survived = data.groupby(["Destination"])["Survived"].sum()
Destination_Survived
# Out:
# Destination
# Aberdeen, South Dakota, US        0.0
# Aberdeen, Washington, US          1.0
# Akeley, Minnesota, US             0.0
# Akron, Ohio, US                  10.0
# Albany, New York, US              1.0
#                                  ...
# Winnipeg, Manitoba, Canada        6.0
# Woodford County, Kentucky, US     1.0
# Worcester, Massachusetts, US      7.0
# Yonkers, New York, US             2.0
# Youngstown, Ohio, US              6.0
# Name: Survived, Length: 291, dtype: float64

# %%
Pclass_Sex = data.groupby(["Sex"])["Pclass"].sum()
Pclass_Sex
# Out:
# Sex
# female    1004
# male      2000
# Name: Pclass, dtype: int64

# %%
Pclass_Female=data.query("Sex=='female' & Pclass==1")
Pclass_Female
# Out:
#       Survived  Pclass                                               Name  \
# 1          1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3          1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 11         1.0       1                           Bonnell, Miss. Elizabeth
# 31         1.0       1     Spencer, Mrs. William Augustus (Marie Eugenie)
# 52         1.0       1           Harper, Mrs. Henry Sleeper (Myna Haxtun)
# ...        ...     ...                                                ...
# 1288       1.0       1  Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...
# 1291       1.0       1                            Bonnell, Miss. Caroline
# 1293       1.0       1                     Gibson, Miss. Dorothy Winifred
# 1302       1.0       1    Minahan, Mrs. William Edward (Lillian E Thorpe)
# 1305       1.0       1                       Oliva y Ocana, Dona. Fermina
#
#          Sex   Age    Ticket      Fare Embarked                     Hometown  \
# ...

# %% [markdown]
# ### Boarding point

# %%
Boarded_Southampton = data.query("Boarded=='Southampton'")

# %%
Boarded_Southampton
# Out:
#       Survived  Pclass                                             Name  \
# 0          0.0       3                          Braund, Mr. Owen Harris
# 2          1.0       3                           Heikkinen, Miss. Laina
# 3          1.0       1     Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0.0       3                         Allen, Mr. William Henry
# 6          0.0       1                          McCarthy, Mr. Timothy J
# ...        ...     ...                                              ...
# 1302       1.0       1  Minahan, Mrs. William Edward (Lillian E Thorpe)
# 1303       1.0       3                   Henriksson, Miss. Jenny Lovisa
# 1304       1.0       3                               Spector, Mr. Woolf
# 1306       1.0       3                     Saether, Mr. Simon Sivertsen
# 1307       1.0       3                              Ware, Mr. Frederick
#
#          Sex   Age              Ticket     Fare Embarked  \
# ...

# %%
Pclass_3details = data.query("Pclass==3")

# %%
Pclass_3details
# Out:
#       Survived  Pclass                            Name     Sex   Age  \
# 0          0.0       3         Braund, Mr. Owen Harris    male  22.0
# 2          1.0       3          Heikkinen, Miss. Laina  female  26.0
# 4          0.0       3        Allen, Mr. William Henry    male  35.0
# 5          0.0       3                Moran, Mr. James    male  24.0
# 7          0.0       3  Palsson, Master. Gosta Leonard    male   2.0
# ...        ...     ...                             ...     ...   ...
# 1303       1.0       3  Henriksson, Miss. Jenny Lovisa  female  28.0
# 1304       1.0       3              Spector, Mr. Woolf    male  24.0
# 1306       1.0       3    Saether, Mr. Simon Sivertsen    male  38.5
# 1307       1.0       3             Ware, Mr. Frederick    male  24.0
# 1308       1.0       3        Peter, Master. Michael J    male  24.0
#
#                   Ticket     Fare Embarked  \
# 0              A/5 21171   7.2500        S
# 2       STON/O2. 3101282   7.9250        S
# ...

# %%
Pclass_3details_females_survived=Pclass_3details.query("Sex=='female'")
Pclass_3details_females_survived
# Out:
#       Survived  Pclass                                               Name  \
# 2          1.0       3                             Heikkinen, Miss. Laina
# 8          1.0       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10         1.0       3                    Sandstrom, Miss. Marguerite Rut
# 14         0.0       3               Vestrom, Miss. Hulda Amanda Adolfina
# 18         0.0       3  Vander Planke, Mrs. Julius (Emelia Maria Vande...
# ...        ...     ...                                                ...
# 1274       1.0       3                McNamee, Mrs. Neal (Eileen O'Leary)
# 1299       1.0       3                    Riordan, Miss. Johanna Hannah""
# 1300       1.0       3                          Peacock, Miss. Treasteall
# 1301       1.0       3                             Naughton, Miss. Hannah
# 1303       1.0       3                     Henriksson, Miss. Jenny Lovisa
#
#          Sex   Age              Ticket     Fare Embarked  \
# ...

# %%
Pclass_3_Survived_female=data.query("Sex =='female'& 'Pclass_3details' ")
Pclass_3_Survived_female
Pclass_3details_females_survived.groupby(["female"])["Pclass_Female"]
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5704\3567627456.py in <module>
# ----> 1 Pclass_3_Survived_female=data.query("Sex =='female'& 'Pclass_3details' ")
#       2 Pclass_3_Survived_female
#       3 Pclass_3details_females_survived.groupby(["female"])["Pclass_Female"]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in query(self, expr, inplace, **kwargs)
#    4109         kwargs["level"] = kwargs.pop("level", 0) + 1
#    4110         kwargs["target"] = None
# -> 4111         res = self.eval(expr, **kwargs)
#    4112
#    4113         try:
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in eval(self, expr, inplace, **kwargs)
#    4238         kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
#    4239
# -> 4240         return _eval(expr, inplace=inplace, **kwargs)
#    4241
# ...

# %%
age_30=data.query("Age == 30 & Survived==1.0")
age_30.Survived.value_counts()
