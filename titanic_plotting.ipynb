# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('./titanic (1).csv')
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.Ticket.nunique()
# Out:
# 681

# %%
data.Cabin.nunique()
# Out:
# 147

# %%
data.Parch.nunique()
# Out:
# 7

# %%
data.Parch.unique()
# Out:
# array([0, 1, 2, 5, 3, 4, 6], dtype=int64)

# %%
data.drop(columns=['PassengerId','Name','Ticket','Cabin'],inplace=True)
#data.head()

# %%
data.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
data.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.duplicated().sum()
# Out:
# 38

# %%
data.drop_duplicates(inplace=True)

# %%
data.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
data.size
# Out:
# 5392

# %%
data.shape
# Out:
# (674, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 674 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  674 non-null    int64
#  1   Pclass    674 non-null    int64
#  2   Sex       674 non-null    object
#  3   Age       674 non-null    float64
#  4   SibSp     674 non-null    int64
#  5   Parch     674 non-null    int64
#  6   Fare      674 non-null    float64
#  7   Embarked  674 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 47.4+ KB

# %% [markdown]
# ### survived

# %%
sns.histplot(data=data,x='Survived')
plt.show()

# %% [markdown]
# ## Sex vs Survived

# %%
data.Sex.value_counts()
# Out:
# male      421
# female    253
# Name: Sex, dtype: int64

# %%
data.Sex.value_counts().plot.bar('Sex','Survived',figsize=(12,6));

# %%
data.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Embarked'],
#       dtype='object')

# %%
data.Age.nunique()
# Out:
# 88

# %%
female_1_50=data.query("Age>=50 & Sex=='female' & Pclass==1")
female_1_50
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 11          1       1  female  58.0      0      0   26.5500        S
# 177         0       1  female  50.0      0      0   28.7125        C
# 195         1       1  female  58.0      0      0  146.5208        C
# 268         1       1  female  58.0      0      1  153.4625        S
# 275         1       1  female  63.0      1      0   77.9583        S
# 299         1       1  female  50.0      0      1  247.5208        C
# 366         1       1  female  60.0      1      0   75.2500        C
# 496         1       1  female  54.0      1      0   78.2667        C
# 513         1       1  female  54.0      1      0   59.4000        C
# 571         1       1  female  53.0      2      0   51.4792        S
# 591         1       1  female  52.0      1      0   78.2667        C
# 765         1       1  female  51.0      1      0   77.9583        S
# 820         1       1  female  52.0      1      1   93.5000        S
# ...

# %%
female_1_50.plot.area('Survived','Age',figsize=(12,6),cmap='gist_stern');

# %%
female_1_50.sort_values(by='Age').plot.line('Age','Survived',figsize=(12,5),cmap='RdGy_r');

# %%
sns.catplot(data=data,x='Age',y='Sex')
plt.show()

# %%
sns.jointplot(data=data,x='Sex',y='Pclass',color='blue')
plt.show()

# %%
sns.pairplot(data=female_1_50)
plt.show()

# %%
sns.pairplot(data=data)
plt.show()

# %%
data.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
female_survived=data.query("Sex=='female' & Survived==1")
female_survived
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 8           1       3  female  27.0      0      2  11.1333        S
# 9           1       2  female  14.0      1      0  30.0708        C
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 874         1       2  female  28.0      1      0  24.0000        C
# 875         1       3  female  15.0      0      0   7.2250        C
# 879         1       1  female  56.0      0      1  83.1583        C
# 880         1       2  female  25.0      0      1  26.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
#
# [189 rows x 8 columns]

# %%
sns.relplot(data=female_survived,x='Age',y='Pclass',size='Pclass')
plt.show()

# %%
sns.relplot(data=data,x='Age',y='Pclass',size='Survived')
plt.show()

# %%
sns.relplot(data=female_1_50,x='Age',y='Pclass',size='Survived')
plt.show()

# %%
data.Age.min()
# Out:
# 0.42

# %%
age_10=data.query("Age<=10")
age_10
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 7           0       3    male  2.00      3      1  21.0750        S
# 10          1       3  female  4.00      1      1  16.7000        S
# 16          0       3    male  2.00      4      1  29.1250        Q
# 24          0       3  female  8.00      3      1  21.0750        S
# 43          1       2  female  3.00      1      2  41.5792        C
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 827         1       2    male  1.00      0      2  37.0042        C
# 831         1       2    male  0.83      1      1  18.7500        S
# 850         0       3    male  4.00      4      2  31.2750        S
# 852         0       3  female  9.00      1      1  15.2458        C
# 869         1       3    male  4.00      1      1  11.1333        S
#
# [63 rows x 8 columns]

# %%
sns.countplot(data=age_10,x='Age',hue='Sex')
plt.show()

# %%
sns.countplot(data=age_10,x='Age',hue='Pclass');

# %%
sns.countplot(x='Age',hue='Survived',data=age_10);

# %%
sns.countplot(data=age_10,x='Age',hue='Embarked');

# %%
sns.countplot(data=age_10,x='Fare',hue='Pclass');
plt.xticks(rotation=90)
plt.show()

# %%
persons_with_accompany=data.query("SibSp>=1 & Parch>=1")
persons_with_accompany
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 7           0       3    male   2.0      3      1   21.0750        S
# 10          1       3  female   4.0      1      1   16.7000        S
# 13          0       3    male  39.0      1      5   31.2750        S
# 16          0       3    male   2.0      4      1   29.1250        Q
# 24          0       3  female   8.0      3      1   21.0750        S
# ..        ...     ...     ...   ...    ...    ...       ...      ...
# 850         0       3    male   4.0      4      2   31.2750        S
# 852         0       3  female   9.0      1      1   15.2458        C
# 856         1       1  female  45.0      1      1  164.8667        S
# 869         1       3    male   4.0      1      1   11.1333        S
# 871         1       1  female  47.0      1      1   52.5542        S
#
# [125 rows x 8 columns]

# %%
sns.countplot(data=persons_with_accompany,x='SibSp',hue='Sex');

# %%
sns.barplot(x='Pclass',y='Survived',data=data);

# %%
sns.barplot(x='Sex',y='Pclass',hue='Survived',data=data);

# %%
pclass_survived=data.groupby(['Pclass'])['Survived'].sum()
pclass_survived.plot.pie(legend=True,autopct='%1.2f%%');

# %%
sns.scatterplot(x='Age',y='Pclass',data=data);

# %%
sns.regplot(x='Age',y='Fare',data=age_10);

# %%
sns.scatterplot(x='Age',y='Fare',hue='Sex',data=age_10);

# %%
sns.scatterplot(x='Age',y='Pclass',hue='Age',data=age_10,size='Age');

# %%
sns.scatterplot(x='Age',y='Fare',hue='Age',size='Age',data=data);

# %%
sns.regplot(x='Age',y='Fare',data=data);
